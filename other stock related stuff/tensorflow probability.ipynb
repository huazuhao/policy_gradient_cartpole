# %%
import tensorflow_probability as tfp
tfd = tfp.distributions

a = 0.5
b = 0.5


dist = tfd.Kumaraswamy(a, b)

# %%
sample = dist.sample(1).numpy()
print(sample[0])
# Out:
# 0.9666075

# %%
sample = dist.sample(1000).numpy()

# %%
import matplotlib.pyplot as plt

plt.hist(sample,bins = 100)
plt.show()

# %%
from scipy.stats import uniform

sample = []

for _ in range(0,1000):
    
    #now we sample
    r = uniform.rvs(size = 1)
    action = (1-(1-r)**(1/b))**(1/a) #solve for the cdf of the distribution
    
    sample.append(action[0])

# %%
plt.hist(sample,bins = 100)
plt.show()

# %%
total = []
total.append(-1.9035814737979846)
total.append(-1.9460032745772282)
total.append(-1.7504510313091566)
total.append(-1.9033340470296602)
total.append(-1.550558926855354)
total.append(-1.817124855313913)
total.append(-1.7554849723045998)
total.append(-1.6898520216779431)
total.append(-1.7285440494421622)
total.append(-1.7360562323495956)
total.append(-1.5820429023520393)
total.append(-1.7157205186618818)
total.append(-1.6750535887772064)
total.append(-1.5821909723999852)
total.append(-1.6598822922494036)
total.append(-1.8297155000566996)
total.append(-1.52057913647362)
total.append(-1.6859550226979432)
total.append(-1.5602323265505151)
total.append(-1.7869660986838307)
total.append(-1.400791422405267)
total.append(-1.6938527484109613)
total.append(-1.5911318975905326)
total.append(-1.555763305578735)
total.append(-1.661510838890379)
total.append(-1.5145585336368055)
total.append(-1.2712828954608606)
total.append(-1.5242761770349205)
total.append(-1.3889668654239855)
total.append(-1.2618339110710408)

plt.plot(total)
plt.show()

# %%
total_reward = []

total_reward.append( -1.9969759550008124 )
total_reward.append( -1.8760364332145074 )
total_reward.append( -1.8540188319261481 )
total_reward.append( -1.8028568714527058 )
total_reward.append( -1.7720880056791628 )
total_reward.append( -1.7288636133170439 )
total_reward.append( -1.7303926079745358 )
total_reward.append( -1.893829679324618 )
total_reward.append( -1.9040509572592288 )
total_reward.append( -1.8512932847972123 )
total_reward.append( -1.7116143731940376 )
total_reward.append( -1.808810707272802 )
total_reward.append( -1.7372328867796565 )
total_reward.append( -1.6497180982615616 )
total_reward.append( -1.6865946565933962 )
total_reward.append( -1.6389015064919346 )
total_reward.append( -1.6633875178613389 )
total_reward.append( -1.7352039777194184 )
total_reward.append( -1.5188643493430405 )
total_reward.append( -1.8488430872074928 )
total_reward.append( -1.4498456375391593 )
total_reward.append( -1.648925452838978 )
total_reward.append( -1.5936401855794597 )
total_reward.append( -1.5599216081436194 )
total_reward.append( -1.5127092245907559 )
total_reward.append( -1.541234775104573 )
total_reward.append( -1.5889759782270725 )
total_reward.append( -1.5619074496296113 )
total_reward.append( -1.5055197685863397 )
total_reward.append( -1.5616893628341797 )
total_reward.append( -1.5886001157250789 )
total_reward.append( -1.3535634896395363 )
total_reward.append( -1.4982914898212167 )
total_reward.append( -1.3736406105981285 )
total_reward.append( -1.516440185805682 )
total_reward.append( -1.3343998959274248 )
total_reward.append( -1.2833992856687002 )
total_reward.append( -1.480949264454246 )
total_reward.append( -1.314305573253172 )
total_reward.append( -1.3530984903139225 )
total_reward.append( -1.170817930944952 )
total_reward.append( -1.3156026286401794 )
total_reward.append( -1.3780630746882663 )
total_reward.append( -1.333257962760417 )
total_reward.append( -1.4983981606754064 )
total_reward.append( -1.221292906011328 )
total_reward.append( -1.2464759310471571 )
total_reward.append( -1.4711707421430824 )
total_reward.append( -1.2293823952843816 )
total_reward.append( -1.3262637881386086 )
total_reward.append( -1.2614361875059592 )
total_reward.append( -1.3398895632648435 )
total_reward.append( -1.2915704967361037 )
total_reward.append( -1.2679722529792306 )
total_reward.append( -1.2310163734161335 )
total_reward.append( -1.2815160253090374 )
total_reward.append( -1.374443654796833 )
total_reward.append( -1.3126132404165878 )
total_reward.append( -1.37283803393365 )
total_reward.append( -1.394256202210342 )
total_reward.append( -1.2609223925981299 )
total_reward.append( -1.399746761510731 )
total_reward.append( -1.4136202738987647 )
total_reward.append( -1.361741336455485 )
total_reward.append( -1.2738384813444297 )
total_reward.append( -1.4180456645722757 )
total_reward.append( -1.2549257778195455 )
total_reward.append( -1.3451385134897178 )
total_reward.append( -1.3979196373558958 )
total_reward.append( -1.4338458709678454 )
total_reward.append( -1.518733642142174 )
total_reward.append( -1.5932277340615344 )
total_reward.append( -1.7600124829667747 )
total_reward.append( -1.6287472690984806 )
total_reward.append( -1.5196202802743375 )
total_reward.append( -1.4930664503857864 )
total_reward.append( -1.4429059960192203 )
total_reward.append( -1.4454795921508496 )
total_reward.append( -1.7967742507226883 )
total_reward.append( -1.597686746644297 )
total_reward.append( -1.6521483173484284 )
total_reward.append( -1.654270535567932 )
total_reward.append( -1.7983665813076084 )
total_reward.append( -1.4745675905806004 )
total_reward.append( -1.6411961896621188 )
total_reward.append( -1.6036106872353342 )
total_reward.append( -1.8266940000586767 )
total_reward.append( -1.6927238639601623 )
total_reward.append( -1.778573859796581 )
total_reward.append( -1.642404905697611 )
total_reward.append( -1.715717790942436 )
total_reward.append( -2.360691357074145 )
total_reward.append( -2.056627496155748 )
total_reward.append( -2.2209484787493476 )
total_reward.append( -2.1766500372038298 )
total_reward.append( -2.7034455703870113 )
total_reward.append( -2.8400199855660975 )
total_reward.append( -2.638484553068549 )
total_reward.append( -2.3947283464397118 )
total_reward.append( -2.569180322380367 )


plt.plot(total_reward)
plt.xlabel('iteration')
plt.ylabel('reward')
plt.show()
print(len(total_reward))
# Out:
# 100
