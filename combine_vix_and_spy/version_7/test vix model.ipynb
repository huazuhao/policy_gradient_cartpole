# %%
import pickle

# %%
with open('lifeline_model.pickle', 'rb') as f:
    cph = pickle.load(f)

# %%
last_valid_data = 54

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
original_testing_data = pd.read_csv('full_feature_dataframe_lifeline_testing.csv')

# %%
original_testing_data.shape
# Out:
# (2759, 60)

# %%
original_testing_data.shape[0]/7
# Out:
# 394.14285714285717

# %%
plt.rcParams["figure.figsize"] = (15,8)

fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_xlabel('Hour')
ax1.set_ylabel('vix index', color=color)
ax1.plot(original_testing_data['VIXY_BID_close'], color=color)
ax1.tick_params(axis='y', labelcolor=color)


ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('plot 1 minus prediction', color=color)  # we already handled the x-label with ax1
ax2.plot(original_testing_data['SPY_BID_close'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  # otherwise the right y-label is slightly clipped

#ax2.hlines(0.5,0,len(plot_prediction),colors = 'black')


plt.show()

# %%
plot_prediction = []

for event_index in range(0,original_testing_data.shape[0]):
    
    prediction = cph.predict_survival_function(original_testing_data.iloc[event_index,2:last_valid_data])[event_index].tolist()
    prediction = np.mean(prediction[-10:])
    
    plot_prediction.append(prediction)

# %%
interval = 1000

for some_index in range(0,original_testing_data.shape[0],interval):

    plot_begin = some_index
    plot_end = some_index+interval



    plt.rcParams["figure.figsize"] = (15,8)

    fig, ax1 = plt.subplots()
    color = 'tab:red'
    ax1.set_xlabel('Hour')
    ax1.set_ylabel('vix index', color=color)
    ax1.plot(original_testing_data['SPY_BID_close'].tolist()[plot_begin:plot_end], color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    #ax1.hlines(6,0,len(plot_prediction),colors = 'black')


    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
    color = 'tab:blue'
    ax2.set_ylabel('plot 1 minus prediction', color=color)  # we already handled the x-label with ax1
    ax2.plot(plot_prediction[plot_begin:plot_end], color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    fig.tight_layout()  # otherwise the right y-label is slightly clipped

    #ax2.hlines(0.5,0,len(plot_prediction),colors = 'black')


    plt.show()

# %%
plot_prediction = []

for event_index in range(0,original_testing_data.shape[0]):
    
    prediction = cph.predict_survival_function(original_testing_data.iloc[event_index,2:last_valid_data])[event_index].tolist()
    prediction = np.mean(prediction[-20:])
    
    plot_prediction.append(prediction)

# %%
interval = 1000

for some_index in range(0,original_testing_data.shape[0],interval):

    plot_begin = some_index
    plot_end = some_index+interval



    plt.rcParams["figure.figsize"] = (15,8)

    fig, ax1 = plt.subplots()
    color = 'tab:red'
    ax1.set_xlabel('Hour')
    ax1.set_ylabel('vix index', color=color)
    ax1.plot(original_testing_data['SPY_BID_close'].tolist()[plot_begin:plot_end], color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    #ax1.hlines(6,0,len(plot_prediction),colors = 'black')


    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
    color = 'tab:blue'
    ax2.set_ylabel('plot 1 minus prediction', color=color)  # we already handled the x-label with ax1
    ax2.plot(plot_prediction[plot_begin:plot_end], color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    fig.tight_layout()  # otherwise the right y-label is slightly clipped

    #ax2.hlines(0.5,0,len(plot_prediction),colors = 'black')


    plt.show()

# %%
plot_prediction = []

for event_index in range(0,original_testing_data.shape[0]):
    
    prediction = cph.predict_survival_function(original_testing_data.iloc[event_index,2:last_valid_data])[event_index].tolist()
    prediction = np.mean(prediction[-30:])
    
    plot_prediction.append(prediction)

# %%
interval = 1000

for some_index in range(0,original_testing_data.shape[0],interval):

    plot_begin = some_index
    plot_end = some_index+interval



    plt.rcParams["figure.figsize"] = (15,8)

    fig, ax1 = plt.subplots()
    color = 'tab:red'
    ax1.set_xlabel('Hour')
    ax1.set_ylabel('vix index', color=color)
    ax1.plot(original_testing_data['SPY_BID_close'].tolist()[plot_begin:plot_end], color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    #ax1.hlines(6,0,len(plot_prediction),colors = 'black')


    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
    color = 'tab:blue'
    ax2.set_ylabel('plot 1 minus prediction', color=color)  # we already handled the x-label with ax1
    ax2.plot(plot_prediction[plot_begin:plot_end], color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    fig.tight_layout()  # otherwise the right y-label is slightly clipped

    #ax2.hlines(0.5,0,len(plot_prediction),colors = 'black')


    plt.show()

# %%
plot_prediction = []

for event_index in range(0,original_testing_data.shape[0]):
    
    prediction = cph.predict_survival_function(original_testing_data.iloc[event_index,2:last_valid_data])[event_index].tolist()
    prediction = np.mean(prediction[-5:])
    
    plot_prediction.append(prediction)

# %%
interval = 1000

for some_index in range(0,original_testing_data.shape[0],interval):

    plot_begin = some_index
    plot_end = some_index+interval



    plt.rcParams["figure.figsize"] = (15,8)

    fig, ax1 = plt.subplots()
    color = 'tab:red'
    ax1.set_xlabel('Hour')
    ax1.set_ylabel('vix index', color=color)
    ax1.plot(original_testing_data['SPY_BID_close'].tolist()[plot_begin:plot_end], color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    #ax1.hlines(6,0,len(plot_prediction),colors = 'black')


    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
    color = 'tab:blue'
    ax2.set_ylabel('plot 1 minus prediction', color=color)  # we already handled the x-label with ax1
    ax2.plot(plot_prediction[plot_begin:plot_end], color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    fig.tight_layout()  # otherwise the right y-label is slightly clipped

    #ax2.hlines(0.5,0,len(plot_prediction),colors = 'black')


    plt.show()
