# %%
import pandas as pd

# %%
index_feature_dataframe = pd.read_csv("full_feature_dataframe.csv")

# %%
index_feature_dataframe.iloc[10]
# Out:
# Unnamed: 0                                                                      10
# date                                                            20180215  11:00:00
# vix_index_close                                                              19.67
# vix_index_10_slope                                                       -0.124848
# vix_index_30_slope                                                       -0.545898
# vix_index_50_slope                                                       -0.225157
# vix_index_100_slope                                                       0.174346
# vix_index_200_slope                                                       0.103905
# vix_index_iv_close                                                        1.219638
# vix_index_mv_ratio                                                        4.405332
# vix_index_intervals_since_5.5                                                   42
# ...

# %%
index_feature_dataframe.iloc[10][2:25]
# Out:
# vix_index_close                     19.67
# vix_index_10_slope              -0.124848
# vix_index_30_slope              -0.545898
# vix_index_50_slope              -0.225157
# vix_index_100_slope              0.174346
# vix_index_200_slope              0.103905
# vix_index_iv_close               1.219638
# vix_index_mv_ratio               4.405332
# vix_index_intervals_since_5.5          42
# vix_index_intervals_since_6            37
# vix_index_intervals_since_6.5          28
# vixy_mid_close_10_slope         -1.712242
# vixy_mid_close_30_slope         -1.228258
# vixy_mid_close_50_slope         -0.166787
# vixy_mid_close_100_slope         0.871913
# vixy_mid_close_200_slope         0.437394
# vixy_iv_close                    0.807489
# spy_mid_close_10_slope           0.567758
# spy_mid_close_30_slope           0.424836
# spy_mid_close_50_slope           0.038451
# spy_mid_close_100_slope         -0.260759
# spy_mid_close_200_slope         -0.057994
# ...

# %%
index_feature_dataframe.iloc[10][25]
# Out:
# 138.92

# %%
index_feature_dataframe.iloc[10][26]
# Out:
# 139.04

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,8)

# %%
plt.plot(index_feature_dataframe['vix_index_intervals_since_5.5'])
plt.show()

# %%
plt.plot(index_feature_dataframe['vix_index_intervals_since_6'])
plt.show()

# %%
plt.plot(index_feature_dataframe['vix_index_intervals_since_6.5'])
plt.show()

# %%
plt.plot(index_feature_dataframe['vix_index_intervals_since_6.5'][-1000:],label = '6.5')
plt.plot(index_feature_dataframe['vix_index_intervals_since_6'][-1000:],label = '6')
plt.plot(index_feature_dataframe['vix_index_intervals_since_5.5'][-1000:],label = '5.5')
plt.legend()
plt.show()

# %%
import numpy as np

# %%
np.asarray([999]*(index_feature_dataframe.shape[1]-6))
# Out:
# array([999, 999, 999, 999, 999, 999, 999, 999, 999, 999, 999, 999, 999,
#        999, 999, 999, 999, 999, 999, 999, 999, 999, 999, 999])

# %%
import trading_vix_env

# %%
local_env = trading_vix_env.trading_vix_env()
# Out:
# /home/zuhao/anaconda2/envs/p37/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
local_env.observation_space
# Out:
# Box(-9999.0, 9999.0, (24,), float32)

# %%
local_env.reset().shape
# Out:
# (24,)

# %%
local_env.observation_space
# Out:
# Box(-9999.0, 9999.0, (24,), float32)
