# %%
import jsonpickle

# %%
optimization_process_file_name = 'optimization_history.json'

# %%
optimization_history_dict = jsonpickle.decode(open(optimization_process_file_name).read())

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
objective_history = optimization_history_dict['objective_history']

# %%
fig = plt.figure(figsize=(7, 5))
matplotlib.rcParams.update({'font.size': 16})
plt.plot(objective_history, 'b.', ms=10)  # Plot all evaluated points as blue dots
plt.plot(np.maximum.accumulate(objective_history), 'r', lw=3)  # Plot cumulative minimum as a red line
plt.xlim([0, len(objective_history)])
plt.ylim([0, np.max(objective_history)])
plt.title("linear trpo")

plt.tight_layout()
plt.show()

# %%
plt.plot(objective_history)
plt.ylim([0, np.max(objective_history)])
plt.show()

# %%
max(objective_history)
# Out:
# 261.3471581861314

# %%
mean_history = optimization_history_dict['mean_history']

# %%
fig = plt.figure(figsize=(7, 5))
matplotlib.rcParams.update({'font.size': 16})
plt.plot(mean_history, 'b.', ms=10)  # Plot all evaluated points as blue dots
plt.plot(np.maximum.accumulate(mean_history), 'r', lw=3)  # Plot cumulative minimum as a red line
plt.xlim([0, len(mean_history)])
plt.ylim([0, np.max(objective_history)])
plt.title("mean_history")

plt.tight_layout()
plt.show()

# %%
plt.plot(mean_history)
plt.ylim([0, np.max(objective_history)])
plt.show()

# %%
max(mean_history)
# Out:
# 261.3471581861314

# %%
np.argmax(mean_history)
# Out:
# 1547

# %%
np.argmax(objective_history)
# Out:
# 1547
