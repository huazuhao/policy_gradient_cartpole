# %%
import jsonpickle

# %%
optimization_process_file_name = 'policy_gradient_optimization_history.json'

# %%
episode_rewards_dict = jsonpickle.decode(open(optimization_process_file_name).read())

# %%
episode_rewards = episode_rewards_dict['episode_rewards']

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.plot(episode_rewards)
plt.plot(np.maximum.accumulate(episode_rewards), 'r', lw=3)  # Plot cumulative minimum as a red line
plt.show()

# %%
N = 20
cumsum, moving_aves = [0], []

for i, x in enumerate(episode_rewards, 1):
    cumsum.append(cumsum[i-1] + x)
    if i>=N:
        moving_ave = (cumsum[i] - cumsum[i-N])/N
        #can do stuff with moving_ave here
        moving_aves.append(moving_ave)
    else:
        moving_aves.append(cumsum[1])

# %%
print(len(moving_aves))
print(len(episode_rewards))
# Out:
# 300
# 300

# %%
plt.plot(episode_rewards)
plt.plot(moving_aves)
plt.show()
